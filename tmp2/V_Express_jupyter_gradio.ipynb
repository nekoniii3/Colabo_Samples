# %% [markdown]
# <a href="https://colab.research.google.com/github/nekoniii3/Colabo_Samples/blob/main/tmp2/V_Express_jupyter_gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **V_Express-Jupyter-Gradio**
# This is a modification of https://colab.research.google.com/github/camenduru/V-Express-jupyter/

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/V-Express
# %cd /content/V-Express

# !apt -y install -qq aria2

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/insightface_models/models/buffalo_l/1k3d68.onnx -d /content/V-Express/model_ckpts/insightface_models/models/buffalo_l -o 1k3d68.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/insightface_models/models/buffalo_l/2d106det.onnx -d /content/V-Express/model_ckpts/insightface_models/models/buffalo_l -o 2d106det.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/insightface_models/models/buffalo_l/det_10g.onnx -d /content/V-Express/model_ckpts/insightface_models/models/buffalo_l -o det_10g.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/insightface_models/models/buffalo_l/genderage.onnx -d /content/V-Express/model_ckpts/insightface_models/models/buffalo_l -o genderage.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/insightface_models/models/buffalo_l/w600k_r50.onnx -d /content/V-Express/model_ckpts/insightface_models/models/buffalo_l -o w600k_r50.onnx

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/sd-vae-ft-mse/config.json -d /content/V-Express/model_ckpts/sd-vae-ft-mse -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.bin -d /content/V-Express/model_ckpts/sd-vae-ft-mse -o diffusion_pytorch_model.bin

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/stable-diffusion-v1-5/unet/config.json -d /content/V-Express/model_ckpts/stable-diffusion-v1-5/unet -o config.json

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/v-express/audio_projection.pth -d /content/V-Express/model_ckpts/v-express -o audio_projection.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/v-express/denoising_unet.pth -d /content/V-Express/model_ckpts/v-express -o denoising_unet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/v-express/motion_module.pth -d /content/V-Express/model_ckpts/v-express -o motion_module.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/v-express/reference_net.pth -d /content/V-Express/model_ckpts/v-express -o reference_net.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/v-express/v_kps_guider.pth -d /content/V-Express/model_ckpts/v-express -o v_kps_guider.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/wav2vec2-base-960h/config.json -d /content/V-Express/model_ckpts/wav2vec2-base-960h -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/wav2vec2-base-960h/feature_extractor_config.json -d /content/V-Express/model_ckpts/wav2vec2-base-960h -o feature_extractor_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/wav2vec2-base-960h/preprocessor_config.json -d /content/V-Express/model_ckpts/wav2vec2-base-960h -o preprocessor_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/resolve/main/wav2vec2-base-960h/pytorch_model.bin -d /content/V-Express/model_ckpts/wav2vec2-base-960h -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/wav2vec2-base-960h/special_tokens_map.json -d /content/V-Express/model_ckpts/wav2vec2-base-960h -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/wav2vec2-base-960h/tokenizer_config.json -d /content/V-Express/model_ckpts/wav2vec2-base-960h -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/V-Express/raw/main/wav2vec2-base-960h/vocab.json -d /content/V-Express/model_ckpts/wav2vec2-base-960h -o vocab.json

# Gradio追加
# !pip install gradio==4.32.1

# !pip install diffusers==0.24.0 imageio-ffmpeg==0.4.9 insightface==0.7.3 omegaconf==2.2.3 onnxruntime==1.16.3 safetensors==0.4.2 transformers==4.30.2 einops==0.4.1 tqdm==4.66.1 xformers==0.0.26.post1 av accelerate
# Out:
# /content
# Cloning into 'V-Express'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 200 (delta 6), reused 5 (delta 5), pack-reused 191
# Receiving objects: 100% (200/200), 142.80 MiB | 13.17 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# /content/V-Express
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 76629b|OK  |   250MiB/s|/content/V-Express/model_ckpts/insightface_models/models/buffalo_l/1k3d68.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 052355|OK  |    72MiB/s|/content/V-Express/model_ckpts/insightface_models/models/buffalo_l/2d106det.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f6e578|OK  |   230MiB/s|/content/V-Express/model_ckpts/insightface_models/models/buffalo_l/det_10g.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 1240d0|OK  |    29MiB/s|/content/V-Express/model_ckpts/insightface_models/models/buffalo_l/genderage.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# bde339|OK  |   250MiB/s|/content/V-Express/model_ckpts/insightface_models/models/buffalo_l/w600k_r50.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5183d6|OK  |    66KiB/s|/content/V-Express/model_ckpts/sd-vae-ft-mse/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 40383b|OK  |   330MiB/s|/content/V-Express/model_ckpts/sd-vae-ft-mse/diffusion_pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 36ebbe|OK  |    90KiB/s|/content/V-Express/model_ckpts/stable-diffusion-v1-5/unet/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 454b25|OK  |   253MiB/s|/content/V-Express/model_ckpts/v-express/audio_projection.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2b2937|OK  |   366MiB/s|/content/V-Express/model_ckpts/v-express/denoising_unet.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 67ad04|OK  |   461MiB/s|/content/V-Express/model_ckpts/v-express/motion_module.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 865d1b|OK  |   453MiB/s|/content/V-Express/model_ckpts/v-express/reference_net.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b0b1ca|OK  |    39MiB/s|/content/V-Express/model_ckpts/v-express/v_kps_guider.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2b3f7a|OK  |   194KiB/s|/content/V-Express/model_ckpts/wav2vec2-base-960h/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c3662e|OK  |    22KiB/s|/content/V-Express/model_ckpts/wav2vec2-base-960h/feature_extractor_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 407952|OK  |    22KiB/s|/content/V-Express/model_ckpts/wav2vec2-base-960h/preprocessor_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ff4e9b|OK  |   362MiB/s|/content/V-Express/model_ckpts/wav2vec2-base-960h/pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 88bc86|OK  |    11KiB/s|/content/V-Express/model_ckpts/wav2vec2-base-960h/special_tokens_map.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b81913|OK  |    17KiB/s|/content/V-Express/model_ckpts/wav2vec2-base-960h/tokenizer_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 03b0b4|OK  |    40KiB/s|/content/V-Express/model_ckpts/wav2vec2-base-960h/vocab.json
#
# Status Legend:
# (OK):download completed.
# Collecting diffusers==0.24.0
#   Downloading diffusers-0.24.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.5 MB/s eta 0:00:00
# Collecting imageio-ffmpeg==0.4.9
#   Downloading imageio_ffmpeg-0.4.9-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 59.7 MB/s eta 0:00:00
# Collecting insightface==0.7.3
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 46.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting omegaconf==2.2.3
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 11.3 MB/s eta 0:00:00
# Collecting onnxruntime==1.16.3
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 103.9 MB/s eta 0:00:00
# Collecting safetensors==0.4.2
#   Downloading safetensors-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.6 MB/s eta 0:00:00
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 114.1 MB/s eta 0:00:00
# Collecting einops==0.4.1
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting tqdm==4.66.1
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 11.4 MB/s eta 0:00:00
# Collecting xformers==0.0.26.post1
#   Downloading xformers-0.0.26.post1-cp310-cp310-manylinux2014_x86_64.whl (222.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 3.5 MB/s eta 0:00:00
# Collecting av
#   Downloading av-12.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 37.0 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 40.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (3.14.0)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (0.23.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (7.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (1.25.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (2.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg==0.4.9) (67.7.2)
# Collecting onnx (from insightface==0.7.3)
#   Downloading onnx-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 94.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (0.19.3)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (3.0.10)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (1.3.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from insightface==0.7.3) (3.10.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf==2.2.3)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 17.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf==2.2.3) (6.0.1)
# Collecting coloredlogs (from onnxruntime==1.16.3)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.16.3) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.16.3) (24.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.16.3) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime==1.16.3) (1.12.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 115.2 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.10/dist-packages (from xformers==0.0.26.post1) (2.3.0+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->xformers==0.0.26.post1) (4.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->xformers==0.0.26.post1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->xformers==0.0.26.post1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->xformers==0.0.26.post1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0->xformers==0.0.26.post1)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->xformers==0.0.26.post1) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->xformers==0.0.26.post1)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 63.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations->insightface==0.7.3) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations->insightface==0.7.3) (4.10.0.82)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface==0.7.3) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface==0.7.3) (2024.5.22)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->insightface==0.7.3) (1.6.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime==1.16.3)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.24.0) (3.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->insightface==0.7.3) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->insightface==0.7.3) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (2024.6.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->insightface==0.7.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->insightface==0.7.3) (3.5.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime==1.16.3) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->insightface==0.7.3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0->xformers==0.0.26.post1) (2.1.5)
# Building wheels for collected packages: insightface, antlr4-python3-runtime
#   Building wheel for insightface (pyproject.toml) ... done
#   Created wheel for insightface: filename=insightface-0.7.3-cp310-cp310-linux_x86_64.whl size=1054139 sha256=bc45c0bd3c6fe257d7dee3b378d5a38f679277c0ec25a911a2038130cbade340
#   Stored in directory: /root/.cache/pip/wheels/e3/d0/80/e3773fb8b6d1cca87ea1d33d9b1f20a223a6493c896da249b5
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=4fb0b098b77e8c5c5a4e248383fd2a40b3a1ce8a498e9e71a554540cb4f4fc8a
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built insightface antlr4-python3-runtime
# Installing collected packages: tokenizers, einops, antlr4-python3-runtime, tqdm, safetensors, onnx, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, imageio-ffmpeg, humanfriendly, av, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, transformers, onnxruntime, nvidia-cusolver-cu12, diffusers, xformers, insightface, accelerate
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.3
#     Uninstalling safetensors-0.4.3:
#       Successfully uninstalled safetensors-0.4.3
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.5.1
#     Uninstalling imageio-ffmpeg-0.5.1:
#       Successfully uninstalled imageio-ffmpeg-0.5.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed accelerate-0.30.1 antlr4-python3-runtime-4.9.3 av-12.1.0 coloredlogs-15.0.1 diffusers-0.24.0 einops-0.4.1 humanfriendly-10.0 imageio-ffmpeg-0.4.9 insightface-0.7.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 omegaconf-2.2.3 onnx-1.16.1 onnxruntime-1.16.3 safetensors-0.4.2 tokenizers-0.13.3 tqdm-4.66.1 transformers-4.30.2 xformers-0.0.26.post1
# Collecting gradio==4.32.1
#   Downloading gradio-4.32.1-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 30.0 MB/s eta 0:00:00
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.32.1)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (4.2.2)
# Collecting fastapi (from gradio==4.32.1)
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.5 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==4.32.1)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.17.0 (from gradio==4.32.1)
#   Downloading gradio_client-0.17.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 37.6 MB/s eta 0:00:00
# Collecting httpx>=0.24.1 (from gradio==4.32.1)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (0.23.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (1.25.2)
# Collecting orjson~=3.0 (from gradio==4.32.1)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (24.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (2.7.3)
# Collecting pydub (from gradio==4.32.1)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart>=0.0.9 (from gradio==4.32.1)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio==4.32.1)
#   Downloading ruff-0.4.8-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 108.9 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio==4.32.1)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.32.1)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Collecting typer<1.0,>=0.12 (from gradio==4.32.1)
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (4.12.1)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.32.1) (2.0.7)
# Collecting uvicorn>=0.14.0 (from gradio==4.32.1)
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.17.0->gradio==4.32.1) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.17.0->gradio==4.32.1)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.32.1) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.32.1) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.32.1) (0.12.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.1) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.1) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio==4.32.1)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.1) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.32.1) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio==4.32.1)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.32.1) (3.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.32.1) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.32.1) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.32.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.32.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.32.1) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.32.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.32.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.32.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.32.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.32.1) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.32.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.32.1) (2.18.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==4.32.1) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio==4.32.1)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio==4.32.1) (13.7.1)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio==4.32.1)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 9.8 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio==4.32.1)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->gradio==4.32.1)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.1 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi->gradio==4.32.1)
#   Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio==4.32.1)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 41.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.32.1) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.32.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.32.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.32.1) (0.18.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.32.1) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.32.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.32.1) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio==4.32.1) (1.2.1)
# Collecting httptools>=0.5.0 (from uvicorn>=0.14.0->gradio==4.32.1)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 37.6 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn>=0.14.0->gradio==4.32.1)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn>=0.14.0->gradio==4.32.1)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 104.8 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn>=0.14.0->gradio==4.32.1)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 83.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.32.1) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.32.1) (0.1.2)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=0c4e3f3b1875a42bfee48d371b1b4b388cf548d1c3cfa73293a46d334c01084f
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, uvloop, ujson, tomlkit, shellingham, semantic-version, ruff, python-multipart, python-dotenv, orjson, httptools, h11, dnspython, aiofiles, watchfiles, uvicorn, starlette, httpcore, email_validator, typer, httpx, gradio-client, fastapi-cli, fastapi, gradio
# ERROR: Operation cancelled by user

# %%
# !pip install gradio==4.32.1

# %% [markdown]
# # **①画像と音声のみで動画を生成（シナリオ2）**
# Generate videos using only images and audio（Scenario2）

# %%
# %cd /content/V-Express

import gradio as gr
import os
import datetime
from zoneinfo import ZoneInfo

dt = datetime.datetime.now(ZoneInfo("Asia/Tokyo"))
fol_name = dt.strftime("%Y%m%d%H%M%S")

def fix_face_video(input_image, input_audio):

    retarget_strategy = "fix_face"
    num_inference_steps = 25

    dt = datetime.datetime.now(ZoneInfo("Asia/Tokyo"))
    fol_name = dt.strftime("%Y%m%d")
    file_name = dt.strftime("%H%M%S")

    out_video = "./output/" + fol_name+ "/fix_face_" + file_name + ".mp4"
    # print("out_video_name："out_video)

    # !python inference.py \
        --reference_image_path $input_image \
        --audio_path $input_audio \
        --output_path $out_video \
        --retarget_strategy $retarget_strategy \
        --num_inference_steps $num_inference_steps

    return out_video

image = gr.Image(label="対象画像(jpg, png)", type="filepath")
audio = gr.File(label="音声ファイル(mp3)", file_types=[".mp3", ".MP3"])
out_video = gr.Video(label="Fix Face Video")
btn = gr.Button("送信", variant="primary")

title = "V_Express Scenario2"
description = "<div style='text-align: center;'><h3>これは公式のシナリオ2（画像と話す音声による生成）のみ対応しています。"
description += "<br>This only supports official Scenario 2 (Generated from images and speaking voices).</h3></div>"

demo = gr.Interface(
    fn=fix_face_video,
    inputs=[image, audio],
    outputs=[out_video],
    title=title,
    submit_btn=btn,
    clear_btn=None,
    description=description,
    allow_flagging="never"
)

demo.queue()
demo.launch(share=True, debug=True)
# Out:
# /content/V-Express
# Exception in thread Thread-13 (run):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/server.py", line 64, in run
#     self.config.setup_event_loop()
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/config.py", line 477, in setup_event_loop
#     loop_setup(use_subprocess=self.use_subprocess)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/loops/auto.py", line 11, in auto_loop_setup
#     uvloop_setup(use_subprocess=use_subprocess)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/loops/uvloop.py", line 7, in uvloop_setup
#     asyncio.set_event_loop_policy(uvloop.EventLoopPolicy())
# AttributeError: module 'uvloop' has no attribute 'EventLoopPolicy'
# Exception in thread Thread-14 (run):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/server.py", line 64, in run
#     self.config.setup_event_loop()
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/config.py", line 477, in setup_event_loop
#     loop_setup(use_subprocess=self.use_subprocess)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/loops/auto.py", line 11, in auto_loop_setup
#     uvloop_setup(use_subprocess=use_subprocess)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/loops/uvloop.py", line 7, in uvloop_setup
#     asyncio.set_event_loop_policy(uvloop.EventLoopPolicy())
# AttributeError: module 'uvloop' has no attribute 'EventLoopPolicy'
# Exception in thread Thread-15 (run):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/server.py", line 64, in run
#     self.config.setup_event_loop()
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/config.py", line 477, in setup_event_loop
#     loop_setup(use_subprocess=self.use_subprocess)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/loops/auto.py", line 11, in auto_loop_setup
#     uvloop_setup(use_subprocess=use_subprocess)
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/loops/uvloop.py", line 7, in uvloop_setup
#     asyncio.set_event_loop_policy(uvloop.EventLoopPolicy())
# AttributeError: module 'uvloop' has no attribute 'EventLoopPolicy'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-051cbf1bdb8b> in <cell line: 48>()
#      46
#      47 demo.queue()
# ---> 48 demo.launch(share=True, debug=True)
#
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py in launch(self, inline, inbrowser, share, debug, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, height, width, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, allowed_paths, blocked_paths, root_path, app_kwargs, state_session_capacity, share_server_address, share_server_protocol, auth_dependency, max_file_size, _frontend)
#    2319                     local_url,
#    2320                     server,
# -> 2321                 ) = http_server.start_server(
#    2322                     app=self.app,
#    2323                     server_name=server_name,
#
# /usr/local/lib/python3.10/dist-packages/gradio/http_server.py in start_server(app, server_name, server_port, ssl_keyfile, ssl_certfile, ssl_keyfile_password)
#     147                 )
#     148             server = Server(config=config, reloader=reloader)
# --> 149             server.run_in_thread()
#     150             break
#     151         except (OSError, ServerFailedToStartError):
#
# /usr/local/lib/python3.10/dist-packages/gradio/http_server.py in run_in_thread(self)
#      55         start = time.time()
#      56         while not self.started:
# ---> 57             time.sleep(1e-3)
#      58             if time.time() - start > 5:
#      59                 raise ServerFailedToStartError(
#
# KeyboardInterrupt:

# %% [markdown]
# # **②画像・音声・顔の情報で動画を生成（シナリオ1,3）**
# Generate videos using images, voice and face sequences（Scenario1,3）

# %%
# %cd /content/V-Express

import gradio as gr
import os
import datetime
from zoneinfo import ZoneInfo

def ex_kps_audio(input_video):

    fol_name = "kps_and_audio"

    # フォルダ作成
    os.makedirs(fol_name, exist_ok=True)

    input_video_name = os.path.splitext(os.path.basename(input_video))[0]

    out_kps = "./" + fol_name+ "/" + input_video_name + "_kps.pth"
    print(out_kps)

    out_aud = "./" + fol_name+ "/" + input_video_name + "_aud.mp3"
    print(out_aud)

    # !python scripts/extract_kps_sequence_and_audio.py \
        --video_path $input_video \
        --kps_sequence_save_path $out_kps \
        --audio_save_path $out_aud

    return [out_kps, out_aud], out_kps, out_aud

def fix_face_video(retarget_strategy, image, input_kps, input_audio):

    num_inference_steps = 25

    dt = datetime.datetime.now(ZoneInfo("Asia/Tokyo"))
    fol_name = dt.strftime("%Y%m%d")
    file_name = dt.strftime("%H%M%S")

    out_video = "./output/" + fol_name+ "/fix_face_" + file_name + ".mp4"
    print(out_video)

    # !python inference.py \
        --reference_image_path $image \
        --audio_path $input_audio \
        --kps_path $input_kps \
        --output_path $out_video \
        --retarget_strategy $retarget_strategy \
        --num_inference_steps $num_inference_steps

    return out_video

with gr.Blocks() as demo:

    # make audio and face V-kps
    title = "<div style='text-align: center;'><h2>V_Express Scenario1,3</h2></div>"
    description = "<div style='text-align: center;'><h3>これは公式のシナリオ1,3（動画と画像から生成）に対応しています。最初に動画をアップロードして下さい。"
    description += "<br>This supports official Scenario1,3 (Generated from videos and images).Upload the video first.</h3></div>"

    gr.Markdown(title + description)

    with gr.Row():
        input_video = gr.Video(label="Input Video")
        kps_audio_file = gr.Files(label="V-kps and Audio")

    btn_vkps = gr.Button("抽出")

    gr.Markdown("<br><br>")

    # make fix face video
    description = "<div style='text-align: center;'><h3>画像をアップロードして、モードを選んでから実行して下さい。（シナリオ3が\"offset_retarget\"、シナリオ1が\"no_retarget\"）"
    description += "<br>Upload image and select the mode, and run it.（Scenario3 \"offset_retarget\"、Scenario1 が\"no_retarget\"）</h3></div>"

    gr.Markdown(description)

    with gr.Row():
        image = gr.Image(label="対象画像(jpg, png)")
        input_kps = gr.File(label="kps")

    with gr.Row():
        input_audio = gr.File(file_types=[".mp3"], label="音声ファイル")
        out_video = gr.Video(label="Fix Face Video")

    retarget_strategy = gr.Dropdown(label="retarget_strategy", choices=["offset_retarget", "no_retarget"], value = "offset_retarget")

    with gr.Row():
        btn_video = gr.Button("送信（Submit）")
        btn_clear = gr.ClearButton(value="クリア（Clear）", components=[input_kps, input_audio, out_video])

    btn_vkps.click(ex_kps_audio, inputs=[input_video], outputs=[kps_audio_file, input_kps, input_audio])
    btn_video.click(fix_face_video, inputs=[retarget_strategy, image, input_kps, input_audio], outputs=[out_video])


demo.queue()
demo.launch(share=True, debug=True)
# Out:
# [Errno 2] No such file or directory: '/content/V-Express'
# /content
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://2c9d5d4264b166b5b4.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2c9d5d4264b166b5b4.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://2c9d5d4264b166b5b4.gradio.live
